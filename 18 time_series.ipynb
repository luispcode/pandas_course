# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\luisp\\Desktop\\Cursos\\python\\Jupiter_Notebooks\\Curso pandas'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 04E0-B438
#
#  Directory of C:\Users\luisp\Desktop\Cursos\python\Jupiter_Notebooks\db
#
# 03/15/2022  10:27    <DIR>          .
# 03/15/2022  10:27    <DIR>          ..
# 03/15/2022  10:27           224,614 covid_19_data.csv
# 03/12/2022  09:23         1,034,821 london_merged.csv
# 03/10/2022  22:10         4,769,811 Meteorite_landings.csv
# 03/12/2022  17:00            29,719 poblacion.csv
# 03/10/2022  17:17               163 test.csv
# 03/10/2022  21:41            84,959 test.hdf
# 03/10/2022  21:11               388 test.json
# 03/10/2022  21:39             4,639 test.parquet
# 03/10/2022  21:37             1,179 test.pkl
# 03/10/2022  21:11             5,176 text.xlsx
#               10 File(s)      6,155,469 bytes
#                2 Dir(s)  161,506,050,048 bytes free

# %%
df = pd.read_csv('covid_19_data.csv')
df.sample(10)
df['ObservationDate'] = pd.to_datetime(df['ObservationDate'])

# %%
df.dtypes
# Out:
# ObservationDate    datetime64[ns]
# Country/Region             object
# Confirmed                 float64
# Deaths                    float64
# Recovered                 float64
# dtype: object

# %%
list(df)
# Out:
# ['SNo',
#  'ObservationDate',
#  'Province/State',
#  'Country/Region',
#  'Last Update',
#  'Confirmed',
#  'Deaths',
#  'Recovered']

# %%
df = df[[
 'ObservationDate',
 'Country/Region',
 'Confirmed',
 'Deaths',
 'Recovered']]
df
# Out:
#      ObservationDate  Country/Region  Confirmed  Deaths  Recovered
# 0         2020-01-22  Mainland China        1.0     0.0        0.0
# 1         2020-01-22  Mainland China       14.0     0.0        0.0
# 2         2020-01-22  Mainland China        6.0     0.0        0.0
# 3         2020-01-22  Mainland China        1.0     0.0        0.0
# 4         2020-01-22  Mainland China        0.0     0.0        0.0
# ...              ...             ...        ...     ...        ...
# 3390      2020-03-04         Ukraine        1.0     0.0        0.0
# 3391      2020-03-04       Australia        0.0     0.0        0.0
# 3392      2020-03-04              US        0.0     0.0        0.0
# 3393      2020-03-04              US        0.0     0.0        0.0
# 3394      2020-03-04              US        0.0     0.0        0.0
#
# [3395 rows x 5 columns]

# %%
df_time = df.groupby('ObservationDate').sum()
df_time.head(5)
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22           555.0    17.0       28.0
# 2020-01-23           653.0    18.0       30.0
# 2020-01-24           941.0    26.0       36.0
# 2020-01-25          1438.0    42.0       39.0
# 2020-01-26          2118.0    56.0       52.0

# %%
df1 = df_time['Confirmed'].iloc[10:15]
df1
# Out:
# ObservationDate
# 2020-02-01    12038.0
# 2020-02-02    16787.0
# 2020-02-03    19881.0
# 2020-02-04    23892.0
# 2020-02-05    27636.0
# Name: Confirmed, dtype: float64

# %%
df2 = df_time['Deaths'].iloc[12:17]
df1
# Out:
# ObservationDate
# 2020-02-01    12038.0
# 2020-02-02    16787.0
# 2020-02-03    19881.0
# 2020-02-04    23892.0
# 2020-02-05    27636.0
# Name: Confirmed, dtype: float64

# %%
df1 - df2
# Out:
# ObservationDate
# 2020-02-01        NaN
# 2020-02-02        NaN
# 2020-02-03    19455.0
# 2020-02-04    23400.0
# 2020-02-05    27072.0
# 2020-02-06        NaN
# 2020-02-07        NaN
# dtype: float64

# %%
df_time
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22           555.0    17.0       28.0
# 2020-01-23           653.0    18.0       30.0
# 2020-01-24           941.0    26.0       36.0
# 2020-01-25          1438.0    42.0       39.0
# 2020-01-26          2118.0    56.0       52.0
# 2020-01-27          2927.0    82.0       61.0
# 2020-01-28          5578.0   131.0      107.0
# 2020-01-29          6165.0   133.0      126.0
# 2020-01-30          8235.0   171.0      143.0
# 2020-01-31          9925.0   213.0      222.0
# 2020-02-01         12038.0   259.0      284.0
# 2020-02-02         16787.0   362.0      472.0
# 2020-02-03         19881.0   426.0      623.0
# 2020-02-04         23892.0   492.0      852.0
# 2020-02-05         27636.0   564.0     1124.0
# 2020-02-06         30818.0   634.0     1487.0
# 2020-02-07         34392.0   719.0     2011.0
# 2020-02-08         37121.0   806.0     2616.0
# 2020-02-09         40151.0   906.0     3244.0
# ...

# %%
df_time.diff() #calcula la diferencia de un valor con respecto al de la final anterior, en esta caso el dia anterior.
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22             NaN     NaN        NaN
# 2020-01-23            98.0     1.0        2.0
# 2020-01-24           288.0     8.0        6.0
# 2020-01-25           497.0    16.0        3.0
# 2020-01-26           680.0    14.0       13.0
# 2020-01-27           809.0    26.0        9.0
# 2020-01-28          2651.0    49.0       46.0
# 2020-01-29           587.0     2.0       19.0
# 2020-01-30          2070.0    38.0       17.0
# 2020-01-31          1690.0    42.0       79.0
# 2020-02-01          2113.0    46.0       62.0
# 2020-02-02          4749.0   103.0      188.0
# 2020-02-03          3094.0    64.0      151.0
# 2020-02-04          4011.0    66.0      229.0
# 2020-02-05          3744.0    72.0      272.0
# 2020-02-06          3182.0    70.0      363.0
# 2020-02-07          3574.0    85.0      524.0
# 2020-02-08          2729.0    87.0      605.0
# 2020-02-09          3030.0   100.0      628.0
# ...

# %%
df_time.diff().mean()
# Out:
# Confirmed    2251.642857
# Deaths         77.071429
# Recovered    1217.690476
# dtype: float64

# %%
df_diff = df_time.diff()

# %%
df_time.head(1).to_dict()
# Out:
# {'Confirmed': {Timestamp('2020-01-22 00:00:00'): 555.0},
#  'Deaths': {Timestamp('2020-01-22 00:00:00'): 17.0},
#  'Recovered': {Timestamp('2020-01-22 00:00:00'): 28.0}}

# %%
df_diff = df_diff.fillna(
{'Confirmed' : 555.0,
'Deaths' : 17.0,
'Recovered' : 28.0})

# %%
df_diff.cumsum() #suma acumulativa.
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22           555.0    17.0       28.0
# 2020-01-23           653.0    18.0       30.0
# 2020-01-24           941.0    26.0       36.0
# 2020-01-25          1438.0    42.0       39.0
# 2020-01-26          2118.0    56.0       52.0
# 2020-01-27          2927.0    82.0       61.0
# 2020-01-28          5578.0   131.0      107.0
# 2020-01-29          6165.0   133.0      126.0
# 2020-01-30          8235.0   171.0      143.0
# 2020-01-31          9925.0   213.0      222.0
# 2020-02-01         12038.0   259.0      284.0
# 2020-02-02         16787.0   362.0      472.0
# 2020-02-03         19881.0   426.0      623.0
# 2020-02-04         23892.0   492.0      852.0
# 2020-02-05         27636.0   564.0     1124.0
# 2020-02-06         30818.0   634.0     1487.0
# 2020-02-07         34392.0   719.0     2011.0
# 2020-02-08         37121.0   806.0     2616.0
# 2020-02-09         40151.0   906.0     3244.0
# ...

# %%
df_diff.resample('7D').sum() # usar resample definir intervalos de frecuencia para aplicar una operacion, trabajando con series de tiempo como indices.
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22          5578.0   131.0      107.0
# 2020-01-29         18314.0   361.0      745.0
# 2020-02-05         20911.0   621.0     3831.0
# 2020-02-12         30335.0   894.0     9669.0
# 2020-02-19          5277.0   701.0    13553.0
# 2020-02-26         12429.0   452.0    20324.0
# 2020-03-04          2280.0    94.0     2942.0

# %%
df_diff.resample('W-Sun').sum() #suma de valores en cada uno de los domingos.
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-26          2118.0    56.0       52.0
# 2020-02-02         14669.0   306.0      420.0
# 2020-02-09         23364.0   544.0     2772.0
# 2020-02-16         31075.0   864.0     7621.0
# 2020-02-23          7759.0   699.0    12529.0
# 2020-03-01          9386.0   527.0    19322.0
# 2020-03-08          6753.0   258.0     8455.0

# %%
df_diff.resample('M').sum()
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-31          9925.0   213.0      222.0
# 2020-02-29         76088.0  2728.0    39560.0
# 2020-03-31          9111.0   313.0    11389.0

# %%
df_diff.resample('M').count()
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-31              10      10         10
# 2020-02-29              29      29         29
# 2020-03-31               4       4          4

# %% [markdown]
# # Algunas opciones de resample
# # Alias - Description
# B - Business day
# D - Calendar day
# W - Weekly
# M - Month end
# Q - Quarter end
# A - Year end
# BA - Business year end
# AS - Year start
# H - Hourly frequency
# T, min - Minutely frequency
# S - Secondly frequency
# L, ms - Millisecond frequency
# U, us - Microsecond frequency
# N, ns - Nanosecond frequency

# %%
df_diff.resample('M').mean()
# Out:
#                    Confirmed     Deaths    Recovered
# ObservationDate
# 2020-01-31        992.500000  21.300000    22.200000
# 2020-02-29       2623.724138  94.068966  1364.137931
# 2020-03-31       2277.750000  78.250000  2847.250000

# %%
df_cum = df_time.resample('12h').sum(min_count=1)
df_cum
# Out:
#                      Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0    17.0       28.0
# 2020-01-22 12:00:00        NaN     NaN        NaN
# 2020-01-23 00:00:00      653.0    18.0       30.0
# 2020-01-23 12:00:00        NaN     NaN        NaN
# 2020-01-24 00:00:00      941.0    26.0       36.0
# ...                        ...     ...        ...
# 2020-03-02 00:00:00    90309.0  3085.0    45602.0
# 2020-03-02 12:00:00        NaN     NaN        NaN
# 2020-03-03 00:00:00    92844.0  3160.0    48229.0
# 2020-03-03 12:00:00        NaN     NaN        NaN
# 2020-03-04 00:00:00    95124.0  3254.0    51171.0
#
# [85 rows x 3 columns]

# %% [markdown]
# # opciones para rellenar posibles nan:
# df_cum.fillna(-1000)
#
# df_cum.ffill()
#
# df_cum.bfill()

# %%
df_cum = df_cum.interpolate()
df_cum
# Out:
#                      Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22 00:00:00      555.0    17.0       28.0
# 2020-01-22 12:00:00      604.0    17.5       29.0
# 2020-01-23 00:00:00      653.0    18.0       30.0
# 2020-01-23 12:00:00      797.0    22.0       33.0
# 2020-01-24 00:00:00      941.0    26.0       36.0
# ...                        ...     ...        ...
# 2020-03-02 00:00:00    90309.0  3085.0    45602.0
# 2020-03-02 12:00:00    91576.5  3122.5    46915.5
# 2020-03-03 00:00:00    92844.0  3160.0    48229.0
# 2020-03-03 12:00:00    93984.0  3207.0    49700.0
# 2020-03-04 00:00:00    95124.0  3254.0    51171.0
#
# [85 rows x 3 columns]

# %%
df_cum['rate'] = 1 - df_cum['Deaths']/df_cum['Confirmed'] #utilizando una fecha como indice
df_cum
# Out:
#                      Confirmed  Deaths  Recovered      rate
# ObservationDate
# 2020-01-22 00:00:00      555.0    17.0       28.0  0.969369
# 2020-01-22 12:00:00      604.0    17.5       29.0  0.971026
# 2020-01-23 00:00:00      653.0    18.0       30.0  0.972435
# 2020-01-23 12:00:00      797.0    22.0       33.0  0.972396
# 2020-01-24 00:00:00      941.0    26.0       36.0  0.972370
# ...                        ...     ...        ...       ...
# 2020-03-02 00:00:00    90309.0  3085.0    45602.0  0.965840
# 2020-03-02 12:00:00    91576.5  3122.5    46915.5  0.965903
# 2020-03-03 00:00:00    92844.0  3160.0    48229.0  0.965964
# 2020-03-03 12:00:00    93984.0  3207.0    49700.0  0.965877
# 2020-03-04 00:00:00    95124.0  3254.0    51171.0  0.965792
#
# [85 rows x 4 columns]

# %%
df_cum = df_cum.reset_index()
df_cum
# Out:
#        ObservationDate  Confirmed  Deaths  Recovered      rate
# 0  2020-01-22 00:00:00      555.0    17.0       28.0  0.969369
# 1  2020-01-22 12:00:00      604.0    17.5       29.0  0.971026
# 2  2020-01-23 00:00:00      653.0    18.0       30.0  0.972435
# 3  2020-01-23 12:00:00      797.0    22.0       33.0  0.972396
# 4  2020-01-24 00:00:00      941.0    26.0       36.0  0.972370
# ..                 ...        ...     ...        ...       ...
# 80 2020-03-02 00:00:00    90309.0  3085.0    45602.0  0.965840
# 81 2020-03-02 12:00:00    91576.5  3122.5    46915.5  0.965903
# 82 2020-03-03 00:00:00    92844.0  3160.0    48229.0  0.965964
# 83 2020-03-03 12:00:00    93984.0  3207.0    49700.0  0.965877
# 84 2020-03-04 00:00:00    95124.0  3254.0    51171.0  0.965792
#
# [85 rows x 5 columns]

# %%
df_cum.groupby(pd.Grouper(key='ObservationDate', freq = 'M'))[['rate']].mean() #Grouper para usar series de tiempo, utilizando una columna tipo tiempo que no es indice.
# Out:
#                      rate
# ObservationDate
# 2020-01-31       0.974594
# 2020-02-29       0.973562
# 2020-03-31       0.965920

# %%
# ['rate'] serie, [['rate']] data frame.

# %%
sr = df_cum.groupby(pd.Grouper(key='ObservationDate', freq = '1D'))['rate'].mean()
sr.head(7)
# Out:
# ObservationDate
# 2020-01-22    0.970198
# 2020-01-23    0.972416
# 2020-01-24    0.971893
# 2020-01-25    0.971617
# 2020-01-26    0.973103
# 2020-01-27    0.973470
# 2020-01-28    0.977017
# Freq: D, Name: rate, dtype: float64

# %%
sr.plot()
# Out:
# <AxesSubplot:xlabel='ObservationDate'>

# %%
sr.rolling(window=7).mean().plot() #rolling se usa con series de tiempo con indices tipo tiempo.
# Out:
# <AxesSubplot:xlabel='ObservationDate'>

# %%
sr.plot()
sr.rolling(window=7).mean().plot()
sr.rolling(window=14).mean().plot() #rolling se usa con series de tiempo con indices tipo tiempo.
# Out:
# <AxesSubplot:xlabel='ObservationDate'>

# %%
sr.rolling(window=14).apply(lambda x: np.std(x)).plot()
# Out:
# <AxesSubplot:xlabel='ObservationDate'>

# %%
list(df)
# Out:
# ['ObservationDate', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered']

# %%
df.groupby('Country/Region')['Confirmed'].max().sort_values(ascending=False)
# Out:
# Country/Region
# Mainland China    67332.0
# South Korea        5621.0
# Italy              3089.0
# Iran               2922.0
# Others              706.0
#                    ...
# Morocco               1.0
# Nepal                 1.0
# Nigeria               1.0
# Latvia                1.0
# Colombia              0.0
# Name: Confirmed, Length: 90, dtype: float64

# %%
df_time = df.groupby(['Country/Region',
           pd.Grouper(key='ObservationDate', freq='1D')]).sum()
df_time
# Out:
#                                 Confirmed  Deaths  Recovered
# Country/Region ObservationDate
#  Azerbaijan    2020-02-28             1.0     0.0        0.0
# Afghanistan    2020-02-24             1.0     0.0        0.0
#                2020-02-25             1.0     0.0        0.0
#                2020-02-26             1.0     0.0        0.0
#                2020-02-27             1.0     0.0        0.0
# ...                                   ...     ...        ...
# Vietnam        2020-02-29            16.0     0.0       16.0
#                2020-03-01            16.0     0.0       16.0
#                2020-03-02            16.0     0.0       16.0
#                2020-03-03            16.0     0.0       16.0
#                2020-03-04            16.0     0.0       16.0
#
# [1462 rows x 3 columns]

# %%
df_china = df_time.loc['Mainland China',:]
df_china.head()
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-22           547.0    17.0       28.0
# 2020-01-23           639.0    18.0       30.0
# 2020-01-24           916.0    26.0       36.0
# 2020-01-25          1399.0    42.0       39.0
# 2020-01-26          2062.0    56.0       49.0

# %%
ax = df_china.plot(figsize= (10,7), title = 'co', legend = False, style= ['r-', 'g--', 'b:*'])
ax.legend(['1', 'dos', '3'])
plt.xlabel('Date')
plt.ylabel('People')
plt.show()

# %%
df_monthly = df_china.resample('M').max()
df_monthly
# Out:
#                  Confirmed  Deaths  Recovered
# ObservationDate
# 2020-01-31          9783.0   213.0      214.0
# 2020-02-29         79251.0  2835.0    39279.0
# 2020-03-31         80271.0  2981.0    49955.0

# %%
df_monthly.plot(figsize=(10,7), kind='bar', legend=True)
# Out:
# <AxesSubplot:xlabel='ObservationDate'>

# %%
df_monthly.plot(figsize=(10,7), kind='bar', legend=True, stacked=True)
# Out:
# <AxesSubplot:xlabel='ObservationDate'>

# %%
df_monthly['Traitment'] = df_monthly['Confirmed'] - df_monthly['Deaths'] - df_monthly['Recovered']
df_monthly
# Out:
#                  Confirmed  Deaths  Recovered  Traitment
# ObservationDate
# 2020-01-31          9783.0   213.0      214.0     9356.0
# 2020-02-29         79251.0  2835.0    39279.0    37137.0
# 2020-03-31         80271.0  2981.0    49955.0    27335.0

# %%
df_monthly[['Deaths', 'Recovered', 'Traitment']].T.plot(figsize= (10,7), kind = 'pie', subplots=True)
# Out:
# array([<AxesSubplot:ylabel='2020-01-31 00:00:00'>,
#        <AxesSubplot:ylabel='2020-02-29 00:00:00'>,
#        <AxesSubplot:ylabel='2020-03-31 00:00:00'>], dtype=object)

# %%
df_china['rate'] = 1 - df_china['Deaths']/df_china['Confirmed']
df_china['rate'].hist(figsize= (10,7), bins = 10, density= True)
# Out:
# <AxesSubplot:>

# %%
df_china['rate'].plot(kind = 'kde', figsize= (10,7))
# Out:
# <AxesSubplot:ylabel='Density'>
